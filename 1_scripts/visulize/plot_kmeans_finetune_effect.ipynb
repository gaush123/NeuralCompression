.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.005
, 0.01538
, 0.01308
, 0.59386
, 0.59386
, 0.53758
, 0.538359
, 0.0126
, 0.764201
, 0.0134
, 0.54696
, 0.789561
, 0.52152
, 0.768941
, 0.765761
, 0.770281
, 0.617579
, 0.616719
, 0.625799
, 0.55058
, 0.625319
, 0.777101
, 0.615759
, 0.77546
, 0.794421
, 0.55168
, 0.627499
, 0.77526
, 0.77764
, 0.616019
, 0.77546
, 0.77602
, 0.795361
, 0.797801
, 0.627499
, 0.796662
, 0.627259
, 0.55818
, 0.77404
, 0.799522
, 0.62956
, 0.77836
, 0.7747
, 0.7796
, 0.799662
, 0.779261
, 0.799241
, 0.801641])
accu_before = np.concatenate((accu_before, accu_before_2, accu_before_3))

# %%
accuracy_after = np.array([0.07626
, 0.70526
, 0.782761
, 0.791041
, 0.793821
, 0.795341
, 0.795801
, 0.795541
, 0.795841
, 0.795701
, 0.7123
, 0.788221
, 0.797381
, 0.798962
, 0.801261
, 0.801081
, 0.801701
, 0.801961
, 0.801882
, 0.788262
, 0.797941
, 0.799582
, 0.801241
, 0.802401
, 0.802882
, 0.802701
, 0.803002
, 0.798521
, 0.800502
, 0.801822
, 0.803021
, 0.802682
, 0.803062
, 0.803202
, 0.800322
, 0.802081
, 0.802541
, 0.803041
, 0.802841
, 0.802981
, 0.801782
, 0.802902
, 0.803161
, 0.803261
, 0.803441
, 0.802981
, 0.803221
, 0.803461
, 0.803381
, 0.803201
, 0.803121
, 0.803282
, 0.803121
, 0.803161
, 0.791742
, 0.796842
, 0.791562
, 0.795981
, 0.795981
, 0.796461
, 0.796321
, 0.784621
, 0.793801
, 0.796601
, 0.798181
, 0.797621
, 0.798902])
accuracy_after.size
# Out:
# 67

# %%
plt.ylim([0.75, 0.81])
plt.xlim([0.025, 0.04]) 
plt.scatter(compress_rate, accu_before, color='r',s=5)
# plt.scatter(compress_rate, accuracy_after, color='b')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.ylim([0.75, 0.81])
plt.xlim([0.025, 0.04])

x = np.array(range(64+7) + [87] + [111, 112, 114] + [90] + [118] )
y = np.array(range(54+7) + [87] + [111, 112, 114] + [90] + [118] )
x_axis = np.arange(0,0.1,0.001)
y_line = np.ones(x_axis.shape) * 0.8027
plt.plot(x_axis, y_line, color  ='green')
plt.scatter(compress_rate[y], accu_before[y], color='r',s=25)
plt.scatter(compress_rate[y], accuracy_after, color='b',s=20)
plt.show()

# %%
a = np.where((compress_rate < 0.031) * (compress_rate >0.30) * (accu_before > 0.795))[0]
a
# Out:
# array([ 3, 87])

# %%
a = np.where((compress_rate < 0.031) * (compress_rate >0.030) * (accu_before > 0.795))[0]
a
# Out:
# array([111, 112, 114])

# %%
a = np.where((compress_rate > 0.028) * (compress_rate < 0.029) * (accu_before > 0.787))[0]
a
# Out:
# array([ 4,  5, 54, 56, 57, 58, 60, 90])

# %%
len(y)
# Out:
# 67

# %%
plt.figure(figsize=(16,8))
plt.ylim([0.75, 0.81])
plt.xlim([0.025, 0.06])

y = np.array(range(54+7) + [87] + [111, 112, 114] + [90] + [118] )
comp_new = compress_rate[y]
accu_bef_new = accu_before[y]

bbox = (0.028, 0.0283, 0.789, 0.805)
plt.plot((bbox[0],bbox[1]),(bbox[2],bbox[2]),color='green')
plt.plot((bbox[0],bbox[1]),(bbox[3],bbox[3]),color='green')
plt.plot((bbox[0],bbox[0]),(bbox[2],bbox[3]),color='green')
plt.plot((bbox[1],bbox[1]),(bbox[2],bbox[3]),color='green')
selected= np.where((comp_new < bbox[1]) * (comp_new > bbox[0]) * (accu_bef_new > bbox[2]) * (accu_bef_new < bbox[3]))[0]
print comp_new[selected], accu_bef_new[selected]

plt.scatter(comp_new, accu_bef_new, color='r',s=25)
plt.scatter(comp_new[selected], accu_bef_new[selected], color='b',s=25)
# plt.scatter(compress_rate[y], accuracy_after, color='b',s=20)
plt.show()
# Out:
# [ 0.028168] [ 0.789561]

# %%
len(compress_rate)
# Out:
# 127

# %%
plt.figure(figsize=(16,8))
plt.ylim([0.00, 0.81])
plt.xlim([0.025, 0.06])
x = np.array(range(64+7) + [87] + [111, 112, 114] + [90] + [118] )
y = np.array(range(54+7) + [87] + [111, 112, 114] + [90] + [118] )
comp_new = np.array([0.035676
, 0.036139
, 0.036624
, 0.03715
, 0.03898
, 0.039444
, 0.039928
, 0.040454
, 0.042748
, 0.043233
, 0.043759
, 0.045592
, 0.046055
, 0.046539
, 0.047066
, 0.048901
, 0.049365
, 0.049849
, 0.050375
, 0.05268
, 0.053165
, 0.053691
, 0.056493
, 0.05702
, 0.031919
, 0.032372
, 0.032836
, 0.03332
, 0.033847
, 0.027723
, 0.02728
, 0.026837
, 0.026394
, 0.028168
, 0.030411
, 0.029181
, 0.029097
, 0.02878
])

accu_bef_new = np.array([0.802401
, 0.802882
, 0.802701
, 0.803002
, 0.803021
, 0.802682
, 0.803062
, 0.803142
, 0.803041
, 0.802841
, 0.802981
, 0.802761
, 0.803161
, 0.803261
, 0.803301
, 0.802701
, 0.803221
, 0.803181
, 0.803381
, 0.803201
, 0.803121
, 0.803141
, 0.803081
, 0.803161
, 0.800282
, 0.801021
, 0.801421
, 0.801661
, 0.801701
, 0.784461
, 0.75144
, 0.45228
, 0.01218
, 0.788181
, 0.797801
, 0.796842
, 0.796461
, 0.796321
])

accu_after_new = np.array([0.802401
, 0.802882
, 0.802701
, 0.803002
, 0.803021
, 0.802682
, 0.803062
, 0.803202
, 0.803041
, 0.802841
, 0.802981
, 0.802902
, 0.803161
, 0.803261
, 0.803441
, 0.802981
, 0.803221
, 0.803461
, 0.803381
, 0.803201
, 0.803121
, 0.803282
, 0.803121
, 0.803161
, 0.801261
, 0.801081
, 0.801701
, 0.801961
, 0.801882
, 0.791041
, 0.782761
, 0.70526
, 0.07626
, 0.793801
, 0.798181
, 0.797101
, 0.797901
, 0.797801])
'''
bbox = (0.031, 0.032, 0.789, 0.805)
plt.plot((bbox[0],bbox[1]),(bbox[2],bbox[2]),color='green')
plt.plot((bbox[0],bbox[1]),(bbox[3],bbox[3]),color='green')
plt.plot((bbox[0],bbox[0]),(bbox[2],bbox[3]),color='green')
plt.plot((bbox[1],bbox[1]),(bbox[2],bbox[3]),color='green')
selected= np.where((comp_new < bbox[1]) * (comp_new > bbox[0]) * (accu_bef_new > bbox[2]) * (accu_bef_new < bbox[3]))[0]
print selected
print comp_new[selected], accu_bef_new[selected]
'''
plt.scatter(comp_new, accu_bef_new, color='r',s=25)
plt.scatter(comp_new, accu_after_new, color='b',s=20)
# plt.scatter(comp_new[selected], accu_bef_new[selected], color='b',s=25)


plt.show()

# %%
accu_bef_new.size
# Out:
# 38
